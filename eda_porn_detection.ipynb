# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Exploratory Data Analysis (or smth like that..)

# %% [markdown]
# ### 0) Loading data

# %%
# !unzip /content/drive/MyDrive/Data_files/Porn_data/train.csv.zip
# Out:
# Archive:  /content/drive/MyDrive/Data_files/Porn_data/train.csv.zip
#   inflating: train.csv

# %%
# !unzip /content/drive/MyDrive/Data_files/Porn_data/test.csv.zip
# Out:
# Archive:  /content/drive/MyDrive/Data_files/Porn_data/test.csv.zip
#   inflating: test.csv

# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv("/content/train.csv", index_col=0)
test_df = pd.read_csv("/content/test.csv", index_col=0)

train_df.head(3)
# Out:
#               url                                              title  label
# ID
# 0         m.kp.md  Экс-министр экономики Молдовы - главе МИДЭИ, ц...      0
# 1       www.kp.by  Эта песня стала известна многим телезрителям б...      0
# 2   fanserials.tv  Банши 4 сезон 2 серия Бремя красоты смотреть о...      0

# %% [markdown]
# ### 1) Cleaning data

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135309 entries, 0 to 135308
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   url     135309 non-null  object
#  1   title   135308 non-null  object
#  2   label   135309 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.1+ MB

# %%
train_df[train_df['title'].apply(lambda x: not isinstance(x, str))]
# Out:
#              url title  label
# ID
# 78497  jpg-1.com   NaN      0

# %%
print(not any((train_df['url'].apply(lambda x: not isinstance(x, str)))))   # -> all url's are str
print(not any((train_df['label'].apply(lambda x: x not in (0, 1)))))        # -> all labels are 1 or 0
# Out:
# True
# True

# %%
print(f"all rows: {len(train_df.dropna())}\nrows with NaNs: {len(train_df)}")   # -> only one object containing NaN
train_df = train_df.dropna()
# Out:
# all rows: 135308
# rows with NaNs: 135309

# %%
print(not any(train_df['title'].apply(lambda x: x == '')))                   # -> no empty titles
print(not any(train_df['url'].apply(lambda x: x == '')))                     # -> no empty urls
# Out:
# True
# True

# %% [markdown]
# ### 2) First-step statistics

# %%
# Label distribution on test

train_df['label'].value_counts()
# Out:
# label
# 0    118593
# 1     16715
# Name: count, dtype: int64

# %%
# Here we look at the number of words in titles

title_num_words = train_df['title'].apply(lambda line: len(line.split()))
title_num_words.describe()
# Out:
# count    135308.000000
# mean         10.489727
# std           5.399646
# min           1.000000
# 25%           7.000000
# 50%          10.000000
# 75%          13.000000
# max          54.000000
# Name: title, dtype: float64

# %% [markdown]
# ##### 2.1) Explore url's a bit more..

# %%
# Пробуем сплитить url по точкам и смотреть, сколько чанков получается

url_split_lens = train_df['url'].apply(lambda line: len(line.split('.')))
url_max = url_split_lens.max()
url_min = url_split_lens.min()

print(f"Max '.'-split length: {url_max}, Min '.'-split length: {url_min}")
# Out:
# Max '.'-split length: 11, Min '.'-split length: 1

# %%
train_df[train_df['url'].apply(lambda line: len(line.split('.')) == url_max)]
# Out:
#                                                  url  \
# ID
# 65641  m.m.img1.img1.img1.m.m.m.m.gigporno-video.com
#
#                                                    title  label
# ID
# 65641  Порно мне нравится, только горб на стиральной ...      1

# %%
min_url_len_rows = train_df[train_df['url'].apply(lambda line: len(line.split('.')) == url_min)]
print(len(min_url_len_rows))

min_url_len_rows   # -> Notice: all 0-labeled
# Out:
# 32
#                       url                                              title  \
# ID
# 16537               login                      Платформа Mail.Ru для бизнеса
# 17381             domains  Пользователь a.aborneva@oneproject.kz — Mail.r...
# 18680             domains  Пользователь info@inex.studio — Mail.ru для би...
# 21326             domains  Поиск пользователя «Селетков» — Mail.ru для би...
# 22224               file:     РадиоКот :: Терморегулятор на термопаре К-типа
# 23616               login                      Платформа Mail.Ru для бизнеса
# 24687   poslednie-novosti      Откройте для себя новый рынок сбыта благодаря
# 26155             domains       Поиск пользователя «з» — Mail.ru для бизнеса
# 27075             server2            104 Сменный блок для щетки Lilly латунь
# 32578                  F:  Электросхема.Ру - словари, схемы, справочники,...
# 37417                  C:  Вакансия на должность «разнорабочий» в Артеме ...
# 47933             domains     Поиск пользователя «фтв» — Mail.ru для бизнеса
# 50481             domains  Поиск пользователя «Дягилева Лариса В» — Mail....
# 53068             domains  Поиск пользователя «Галакти» — Mail.ru для биз...
# 62055             domains      Поиск пользователя «yf» — Mail.ru для бизнеса
# 62828      localhost:7784                                         Ошибка 404
# 64172             domains  Поиск пользователя «харитон» — Mail.ru для биз...
# 69478               file:  1. Реферат по книге Эдварда де Боно "Рождение ...
# 72641             domains             Рассылки Sendbox — Mail.ru для бизнеса
# 75324             domains                 Пользователи — Mail.ru для бизнеса
# 76060             domains                 Пользователи — Mail.ru для бизнеса
# 79154             domains  Поиск пользователя «Николаенко Анастасия Серге...
# 93740             domains  Поиск пользователя «дороше» — Mail.ru для бизнеса
# 103957                 C:  Метод порошковой металлургии для спекания изде...
# 110100            domains       Поиск пользователя «g» — Mail.ru для бизнеса
# 110531  poslednie-novosti  Все новинки сезона в новом путеводителе по выс...
# 112490            domains     Поиск пользователя «афо» — Mail.ru для бизнеса
# 112703            domains      Поиск пользователя «ла» — Mail.ru для бизнеса
# 115840                 C:  Горелов А. А., Горелова Т. А. Христианство и с...
# 117758            domains  Пользователь yana.butsykova@opt-ins.ru — Mail....
# 120690            domains       Поиск пользователя «s» — Mail.ru для бизнеса
# 128996              file:  Решебник по математике за 5 класс — Герасимов,...
#
#         label
# ID
# 16537       0
# 17381       0
# 18680       0
# 21326       0
# 22224       0
# 23616       0
# 24687       0
# 26155       0
# 27075       0
# 32578       0
# 37417       0
# 47933       0
# 50481       0
# 53068       0
# 62055       0
# 62828       0
# 64172       0
# 69478       0
# 72641       0
# 75324       0
# 76060       0
# 79154       0
# 93740       0
# 103957      0
# 110100      0
# 110531      0
# 112490      0
# 112703      0
# 115840      0
# 117758      0
# 120690      0
# 128996      0

# %%
url_lens = train_df['url'].apply(lambda line: len(line.split('.')))
url_lens.describe()

# Видим, что, как правило, URL у нас содержит 2-3 чанка
# Out:
# count    135308.000000
# mean          2.399622
# std           0.524617
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max          11.000000
# Name: url, dtype: float64

# %% [markdown]
# ##### 2.2) Try to tokenize urls

# %%
import transformers

model_name = 'DeepPavlov/rubert-base-cased-sentence'
tokenizer = transformers.AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
url_raw = train_df[:10]
url_raw['tokenized_urls'] = url_raw['url'].apply(lambda x: tokenizer(x)['input_ids'])
url_raw
# Out:
# <ipython-input-50-2ee053a49437>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url_raw['tokenized_urls'] = url_raw['url'].apply(lambda x: tokenizer(x)['input_ids'])
#                       url                                              title  \
# ID
# 0                 m.kp.md  Экс-министр экономики Молдовы - главе МИДЭИ, ц...
# 1               www.kp.by  Эта песня стала известна многим телезрителям б...
# 2           fanserials.tv  Банши 4 сезон 2 серия Бремя красоты смотреть о...
# 3         colorbox.spb.ru                              Не Беси Меня Картинки
# 4           tula-sport.ru  В Новомосковске сыграют следж-хоккеисты алекси...
# 5         beregifiguru.ru  Салат: корейская морковь + копченая курица + к...
# 6   ekb.vseinstrumenti.ru  Угловой пневмогайковерт FUBAG RWC 105 1/2" 100...
# 7           mirtabaka.org  Табачный магазин `Мир Табака` | КУРИТЕЛЬНЫЕ ТР...
# 8               xlecx.com  league of legends » Page 5 » Porn comics free ...
# 9       bus.biletyplus.ua  08:00 (4766р), Одесса - Ростов-на-Дону 20 сент...
#
#     label                                     tokenized_urls
# ID
# 0       0      [101, 256, 132, 252, 263, 132, 256, 239, 102]
# 1       0  [101, 276, 277, 277, 132, 252, 263, 132, 10667...
# 2       0  [101, 12723, 11403, 19662, 12259, 132, 20279, ...
# 3       0  [101, 14648, 22468, 132, 33162, 235, 132, 1399...
# 4       0    [101, 13567, 5460, 130, 18437, 132, 13995, 102]
# 5       0  [101, 10859, 69380, 14430, 87064, 12192, 132, ...
# 6       0  [101, 240, 253, 235, 132, 15499, 18404, 49155,...
# 7       0  [101, 36589, 10725, 11049, 10883, 132, 11245, ...
# 8       1        [101, 278, 7159, 237, 279, 132, 10724, 102]
# 9       0  [101, 19881, 132, 11854, 13142, 69150, 14587, ...

# %%
def check_url_tokenization(df, row_num):
    ids = tokenizer(url_raw.iloc[row_num, 0])['input_ids']
    print(ids)
    print([tokenizer.decode(id) for id in ids])

check_url_tokenization(url_raw, 6)
# Out:
# [101, 240, 253, 235, 132, 15499, 18404, 49155, 58591, 249, 132, 13995, 102]
# ['[CLS]', 'e', '##k', '##b', '.', 'vs', '##ein', '##str', '##ument', '##i', '.', 'ru', '[SEP]']

# %% [markdown]
# ### 3) Closer look at sub-dataset with label=1

# %%
porn_detected = train_df[train_df['label'] == 1]
porn_detected.sample(3)
# Out:
#                   url                                              title  \
# ID
# 49185   nudefauna.com                        Flexible Сutie - 116 photos
# 111174    pretty.porn                   old mum XXX Videos - Pretty Porn
# 134654    smurfik.net  ?? Мастурбация красивой девушки - подборка пор...
#
#         label
# ID
# 49185       1
# 111174      1
# 134654      1

# %%
# Посмотрим, как токенизатор работает на порнушных url'ах

tokenized = []
max_iter = 10
curr_iter = 0

for idx, row in porn_detected.iterrows():
    ids = tokenizer(row['url'])['input_ids']
    tokenized.append([tokenizer.decode(id) for id in ids])
    curr_iter += 1
    if curr_iter == max_iter: break

for li in tokenized:
    print(li)
# Out:
# ['[CLS]', 'x', '##le', '##c', '##x', '.', 'com', '[SEP]']
# ['[CLS]', 'por', '##n', '##mu', '##l', '##t', '.', 'info', '[SEP]']
# ['[CLS]', '24', '##ero', '##pi', '##xe', '##l', '.', 'net', '[SEP]']
# ['[CLS]', 'g', '##des', '##pace', '##s', '.', 'com', '[SEP]']
# ['[CLS]', 'h', '##d', '##x', '##cl', '##ub', '.', 'com', '[SEP]']
# ['[CLS]', 'j', '##r', '##f', '##z', '##do', '##h', '##kn', '##t', '##mo', '##p', '##ula', '##m', '##56', '##35', '##ay', '##igs', '##e', '##q', '##r', '##47', '##gh', '##pl', '##fa', '##5', '##l', '##67', '##uo', '##72', '##g', '##c', '##n', '##m', '##cs', '##q', '.', 'cd', '##n', '.', 'amp', '##pro', '##ject', '.', 'org', '[SEP]']
# ['[CLS]', 'des', '##ix', '##xx', '##tu', '##be', '.', 'pro', '[SEP]']
# ['[CLS]', 'i', '##pad', '.', 'per', '##fe', '##kt', '##dam', '##en', '.', 'co', '[SEP]']
# ['[CLS]', 'da', '##ft', '##se', '##x', '.', 'com', '[SEP]']
# ['[CLS]', 'top', '##de', '##v', '##ka', '.', 'com', '[SEP]']
